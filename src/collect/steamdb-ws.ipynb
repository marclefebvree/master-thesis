# %%
# SteamDB web scraper

## Import libraries

from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
import time

# %%
## Test information extraction on single game id

html_text = requests.get('https://steamdb.info/app/570/graphs/').text

soup = BeautifulSoup(html_text, "lxml")

print(soup.prettify())

# need = {}

# for li_tag in html.find_all('ul', {'class':'app-chart-numbers'}):
#     for span_tag in li_tag.find_all('li', {'class':'tooltipped tooltipped-n'}):
#         value = span_tag.find('span', {'class':'number'}).text
#         need[field] = value

# print(need)

appChartObject = soup.find_all(class_="app-chart-numbers")

owners = appChartObject #.contents #[1]#.contents[0].contents[2]

print(owners)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Access denied | steamdb.info used Cloudflare to restrict access
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/cdn-cgi/styles/main.css" id="cf_styles-css" media="screen,projection" rel="stylesheet" type="text/css"/>
#   <script defer="" src="https://api.radar.cloudflare.com/beacon.js">
#   </script>
#  </head>
#  <body>
#   <div id="cf-wrapper">
#    <div class="cf-alert cf-alert-error cf-cookie-error hidden" data-translate="enable_cookies" id="cookie-alert">
#     Please enable cookies.
#    </div>
#    <div class="p-0" id="cf-error-details">
#     <header class="mx-auto pt-10 lg:pt-6 lg:px-8 w-240 lg:w-full mb-15 antialiased">
#      <h1 class="inline-block md:block mr-2 md:mb-2 font-light text-60 md:text-3xl text-black-dark leading-tight">
#       <span data-translate="error">
#        Error
#       </span>
#       <span>
#        1020
#       </span>
#      </h1>
#      <span class="inline-block md:block heading-ray-id font-mono text-15 lg:text-sm lg:leading-relaxed">
#       Ray ID: 6ab8207ab80efa94 •
#      </span>
#      <span class="inline-block md:block heading-ray-id font-mono text-15 lg:text-sm lg:leading-relaxed">
#       2021-11-09 15:38:13 UTC
#      </span>
#      <h2 class="text-gray-600 leading-1.3 text-3xl lg:text-2xl font-light">
#       Access denied
#      </h2>
#     </header>
#     <section class="w-240 lg:w-full mx-auto mb-8 lg:px-8">
#      <div class="w-1/2 md:w-full" id="what-happened-section">
#       <h2 class="text-3xl leading-tight font-normal mb-4 text-black-dark antialiased" data-translate="what_happened">
#        What happened?
#       </h2>
#       <p>
#        This website is using a security service to protect itself from online attacks.
#       </p>
#      </div>
#     </section>
#     <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#      <p class="text-13">
#       <span class="cf-footer-item sm:block sm:mb-1">
#        Cloudflare Ray ID:
#        <strong class="font-semibold">
#         6ab8207ab80efa94
#        </strong>
#       </span>
#       <span class="cf-footer-separator sm:hidden">
#        •
#       </span>
#       <span class="cf-footer-item sm:block sm:mb-1">
#        <span>
#         Your IP
#        </span>
#        : 93.174.95.6
#       </span>
#       <span class="cf-footer-separator sm:hidden">
#        •
#       </span>
#       <span class="cf-footer-item sm:block sm:mb-1">
#        <span>
#         Performance &amp; security by
#        </span>
#        <a href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" rel="noopener noreferrer" target="_blank">
#         Cloudflare
#        </a>
#       </span>
#      </p>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    window._cf_translation = {};
#   </script>
#  </body>
# </html>
#
# []

# %%
## Import game_id.csv

game_id = pd.read_csv('game_id.csv')

## Create dataset with full urls

game_id = game_id.drop('Unnamed: 0', 1)
game_id = game_id.rename(columns = {'steam_ds.appid': 'id'})
game_id['base_url'] = 'https://steamspy.com/app/'
game_id = game_id[['base_url', 'id']]
game_id['full_url'] = game_id['base_url'] + game_id['id'].astype(str) 

print(game_id)

## Create list with full urls

url_list = game_id['full_url'].tolist()
